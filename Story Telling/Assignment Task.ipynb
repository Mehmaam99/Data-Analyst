# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import requests
# import json
# import seaborn as sns
# import ssl
# import numpy as np
# from sklearn import linear_model

# ssl._create_default_https_context = ssl._create_unverified_context

# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# import warnings
# warnings.filterwarnings('ignore')
# from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
# from sklearn import metrics
# from sklearn.metrics import explained_variance_score

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("Petrol.xlsx")

# %%
df
# Out:
#          SiteId                   Site_Name         Site_Brand  \
# 0      61401544     BP Connect Bowen Bridge                 BP
# 1      61401541              Ampol Hamilton              Ampol
# 2      61401359           Caltex Eagle Farm             Caltex
# 3      61401257           7-Eleven Sandgate           7 Eleven
# 4      61401261    Caltex/Woolworths Deagon  Caltex Woolworths
# ...         ...                         ...                ...
# 10664  61402336              Mobil Atherton              Mobil
# 10665  61477009  Caltex/Woolworths Atherton  Caltex Woolworths
# 10666  61402017               Ampol Malanda              Ampol
# 10667  61477771                Eacham Fuels        Independent
# 10668  61402633              Ampol Cooktown              Ampol
#
#             Sites_Address_Line_1 Site_Suburb  Site_Post_Code  Site_Latitude  \
# 0           44 Bowen Bridge Road     Herston            4006     -27.445447
# ...

# %%
df.shape
# Out:
# (10669, 11)

# %%
df['Day'] = pd.DatetimeIndex(df['Date']).day

# %%
df
# Out:
#          SiteId                   Site_Name         Site_Brand  \
# 0      61401544     BP Connect Bowen Bridge                 BP
# 1      61401541              Ampol Hamilton              Ampol
# 2      61401359           Caltex Eagle Farm             Caltex
# 3      61401257           7-Eleven Sandgate           7 Eleven
# 4      61401261    Caltex/Woolworths Deagon  Caltex Woolworths
# ...         ...                         ...                ...
# 10664  61402336              Mobil Atherton              Mobil
# 10665  61477009  Caltex/Woolworths Atherton  Caltex Woolworths
# 10666  61402017               Ampol Malanda              Ampol
# 10667  61477771                Eacham Fuels        Independent
# 10668  61402633              Ampol Cooktown              Ampol
#
#             Sites_Address_Line_1 Site_Suburb  Site_Post_Code  Site_Latitude  \
# 0           44 Bowen Bridge Road     Herston            4006     -27.445447
# ...

# %%
df.Site_Suburb.value_counts()
# Out:
# Caboolture      341
# Virginia        127
# Woodridge       126
# Robina          109
# Acacia Ridge    106
#                ...
# Rubyvale          1
# Middlemount       1
# Deeral            1
# Lake Eacham       1
# Koah              1
# Name: Site_Suburb, Length: 663, dtype: int64

# %%
df['Price'].max()
# Out:
# 999.9

# %%
plt.figure(figsize=(24,10))
sns.scatterplot(x="Site_Brand",y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Site_Brand', ylabel='Price'>

# %%
plt.figure(figsize=(24,10))
sns.barplot(x='Site_Brand',y='Price',data=df)
# Out:
# <AxesSubplot:xlabel='Site_Brand', ylabel='Price'>

# %%
plt.figure(figsize=(24,10))
sns.countplot('Site_Brand',data=df)
# Out:
# C:\Users\syed.mehmaam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Site_Brand', ylabel='count'>

# %%
plt.figure(figsize=(24,10))
sns.countplot('Day',data=df)
# Out:
# C:\Users\syed.mehmaam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day', ylabel='count'>

# %%
plt.figure(figsize=(24,10))
sns.countplot('Day',data=df)
# Out:
# C:\Users\syed.mehmaam\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Day', ylabel='count'>

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10669 entries, 0 to 10668
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   SiteId                10669 non-null  int64
#  1   Site_Name             10669 non-null  object
#  2   Site_Brand            10669 non-null  object
#  3   Sites_Address_Line_1  10669 non-null  object
#  4   Site_Suburb           10669 non-null  object
#  5   Site_Post_Code        10669 non-null  int64
#  6   Site_Latitude         10669 non-null  float64
#  7   Site_Longitude        10669 non-null  float64
#  8   Price                 10669 non-null  float64
#  9   Date                  10669 non-null  datetime64[ns]
#  10  Crude                 10669 non-null  float64
#  11  Day                   10669 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(4)
# memory usage: 1000.3+ KB

# %%
sns.scatterplot(x="Crude",y="Price", data=df)
# Out:
# <AxesSubplot:xlabel='Crude', ylabel='Price'>

# %%
sns.scatterplot(x="Crude",y="Price", data=df)
# Out:
# <AxesSubplot:xlabel='Crude', ylabel='Price'>

# %%
sns.barplot(x="Crude",y="Price", data=df)
# Out:
# <AxesSubplot:xlabel='Crude', ylabel='Price'>

# %%
df.Crude.value_counts()
# Out:
# 124.18082    1031
# 124.92316     932
# 122.67509     597
# 117.69599     585
# 118.06596     575
# 119.22357     554
# 116.51676     550
# 119.80268     520
# 117.81378     479
# 119.45813     467
# 125.07782     453
# 116.98350     351
# 112.34821     344
# 116.81413     340
# 110.98857     288
# 118.13610     287
# 125.48080     285
# 113.63106     280
# 109.95676     277
# 109.43136     253
# 106.85104     239
# 106.38474     221
# 112.75489     183
# 117.05282     135
# 109.44335     134
# 105.58605      95
# 109.92841      90
# 103.99896      78
# 104.31085      46
# Name: Crude, dtype: int64

# %%
df.Site_Brand.value_counts()
# Out:
# 7 Eleven             2341
# BP                   1432
# Coles Express        1399
# Ampol                1142
# Caltex Woolworths    1039
# Puma Energy           847
# Independent           507
# United                455
# Caltex                410
# Freedom Fuels         318
# Metro Fuel            183
# Liberty               146
# Mobil                 133
# Shell                 110
# Pacific Petroleum      64
# Unknown                50
# CQP                    45
# Matilda                20
# Choice                 14
# Enhance                11
# Lowes                   3
# Name: Site_Brand, dtype: int64

# %%
df.Price.value_counts()
# Out:
# 189.9    631
# 169.9    440
# 179.9    434
# 165.9    320
# 185.9    310
#         ...
# 188.2      1
# 181.1      1
# 147.3      1
# 171.2      1
# 184.0      1
# Name: Price, Length: 399, dtype: int64

# %%
df=df[df["Price"]<200]

# %%
df=df[df["Price"]>50]

# %%
df.max()
# Out:
# SiteId                                     61478055
# Site_Name               Zims Corner Service Station
# Site_Brand                                  Unknown
# Sites_Address_Line_1                 Yallambee Road
# Site_Suburb                                Zillmere
# Site_Post_Code                                 4895
# Site_Latitude                            -12.629404
# Site_Longitude                           153.516415
# Price                                         199.9
# Date                            2022-01-31 00:00:00
# Crude                                      125.4808
# Day                                              31
# dtype: object

# %%
df=df[df["Crude"]<200]

# %%
sns.lmplot(x ="Crude", y ="Price", data = df, order = 2, ci = None)

# %%
df.fillna(method ='ffill', inplace = True)

X = np.array(df['Crude']).reshape(-1, 1)
y = np.array(df['Price']).reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SYED~1.MEH\AppData\Local\Temp/ipykernel_9264/3552443377.py in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 regr = LinearRegression()
# ----> 3 regr.fit(X_train, y_train)
#       4 print(regr.score(X_test, y_test))
#       5
#
# NameError: name 'X_train' is not defined

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
  
plt.show()b

# %%
# Day X Crude

# %%
plt.figure(figsize=(24,10))
sns.scatterplot(x="Day",y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Price'>

# %%
plt.figure(figsize=(24,10))
sns.scatterplot(x="Day",y="Crude",data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Crude'>

# %%
sns.barplot(x="Day",y="Crude", data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Crude'>

# %%
sns.lmplot(x ="Day", y ="Crude", data = df, order = 2, ci = None)

# %%
Day = np.array(df['Day']).reshape(-1, 1)
Crude = np.array(df['Crude']).reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
train_1, test_1, train_2, test_2 = train_test_split(Day, Crude, test_size = 0.25)

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
reg_fit=regr.fit(train_1, train_2)
prediction=regr.predict(test_1)

# %%
plt.scatter(prediction,test_2)

# %%
title = 'One Month Retail Prices of OIL 01-01-2022 to 31-01-2022'
import datetime
import random
import matplotlib.pyplot as plt
col1='Day'
plt.figure(figsize=(21,10))
col2='Crude'
y = df["Day"]
x = df['Crude']
plt.plot(x,y)
plt.gca().set_title(title)

plt.show()

# %%
plt.figure(figsize=(8,5))
print('OIL')

score = regr.score(Day, Crude)
score = round(score*100,2)
title = f"Diesel Linear Regression Score = {score}"
plt.title(title)
print('score = {}'.format(score))

coef = regr.coef_
print('coef = {}'.format(coef)) # 1.0
intercept = regr.intercept_

print('intercept = {}'.format(intercept)) # 3.0000...
plt.scatter(Day, Crude, color='gray') # sklearn
y_pred = reg_fit.predict(Day)
plt.plot(Day, y_pred, color='orange') # model
# plt.ylim(0) # start at zero
plt.show()
# Out:
# OIL
# score = 91.72
# coef = [[0.67847482]]
# intercept = [104.5731868]

# %%
reg_fit.predict([[31]])
# Out:
# array([[125.60590629]])
