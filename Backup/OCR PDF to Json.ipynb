# %%
import matplotlib.pyplot as plt
import cv2
import os
import sys
import pytesseract
from pytesseract import Output
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract'

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# %%time
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os
  
# Path of the pdf
PDF_file = "C:\\Users\\Naeem\\OCR\\chem\\paxar.pdf"
  
'''
Part #1 : Converting PDF to images
'''
  
# Store all the pages of the PDF in a variable
pages = convert_from_path(PDF_file, 500)
  
# Counter to store images of each page of PDF to image
image_counter = 1
  
# Iterate through all the pages stored above
for page in pages:
  
    # Declaring filename for each page of PDF as JPG
    # For each page, filename will be:
    # PDF page 1 -> page_1.jpg
    # PDF page 2 -> page_2.jpg
    # PDF page 3 -> page_3.jpg
    # ....
    # PDF page n -> page_n.jpg
    filename = "page_"+str(image_counter)+".jpg"
      
    # Save the image of the page in system
    page.save(filename, 'JPEG',dpi=(300,300))
    #im.save("test-600.png", dpi=(600,600))
    # Increment the counter to update filename
    image_counter = image_counter + 1

'''
Part #2 - Recognizing text from the images using OCR
'''
    
# Variable to get count of total number of pages
filelimit = image_counter-1
  
# Creating a text file to write the output
outfile = "out_text.txt"
  
# Open the file in append mode so that 
# All contents of all images are added to the same file
f = open(outfile, "a")
  
# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):
  
    # Set filename to recognize text from
    # Again, these files will be:
    # page_1.jpg
    # page_2.jpg
    # ....
    # page_n.jpg
    filename = "page_"+str(i)+".jpg"
    
          
    # Recognize the text as string in image using pytesserct
    #text = str(((pytesseract.image_to_string(Image.open(filename)))))
    text = reader.readtext(filename)
    
    
    
    
    print(text)
    print("===============Type=====================",type(text))
    length=len(text)
    print("====================Length===============",length)
    
    # The recognized text is stored in variable text
    # Any string processing may be applied on text
    # Here, basic formatting has been done:
    # In many PDFs, at line ending, if a word can't
    # be written fully, a 'hyphen' is added.
    # The rest of the word is written in the next line
    # Eg: This is a sample text this word here GeeksF-
    # orGeeks is half on first line, remaining on next.
    # To remove this, we replace every '-\n' to ''.
    #text = text.replace('-\n', '')    
    texts=str(text)
    # Finally, write the processed text to the file.
    f.write(texts)
  
# Close the file after writing all the text.
f.close()
# Out:
# [([[3794, 17], [4223, 17], [4223, 72], [3794, 72]], 'Doc#t: FM-L3-SC-01', 0.6615055320260478), ([[67, 0], [727, 0], [727, 168], [67, 168]], 'PAXAR', 0.9653507913381469), ([[4043, 73], [4266, 73], [4266, 128], [4043, 128]], 'Issue#t: 02', 0.6286197248315419), ([[1849, 96], [2512, 96], [2512, 187], [1849, 187]], 'SALES INVOICE', 0.9986565690360795), ([[3717, 129], [4240, 129], [4240, 184], [3717, 184]], 'Issue Date: 25-10-2019', 0.6001695948187612), ([[3717, 245], [4253, 245], [4253, 300], [3717, 300]], 'Paxar Pakistan (Pvt) Ltd_', 0.8802829251126506), ([[67, 286], [1737, 286], [1737, 362], [67, 362]], 'SALES TAX REGISTRATION NO 17-50-5807-003-82', 0.8516076290794506), ([[4047, 301], [4253, 301], [4253, 356], [4047, 356]], 'Plot # 26_', 0.49182517931382186), ([[71, 367], [1050, 367], [1050, 444], [71, 444]], 'NATIONAL TAX NO 2695980-1', 0.6918012370703546), ([[4030, 356], [4253, 356], [4253, 412], [4030, 412]], 'Sector 24', 0.7813849487326464), ([[3744, 410], [4256, 410], [4256, 474], [3744, 474]], 'Korangi Industrial Area,', 0.8060632531234262), ([[334, 489], [559, 489], [559, 555], [334, 555]], 'BILL TO', 0.970271280821506), ([[1902, 493], [2144, 493], [2144, 559], [1902, 559]], 'SHIP TO', 0.9896341478417247), ([[3711, 489], [3940, 489], [3940, 550], [3711, 550]], 'NTN NO_', 0.7103668920232421), ([[333, 586], [1200, 586], [1200, 659], [333, 659]], 'ARTISTIC MILLINERS (PVT) LTD:', 0.9356377691742581), ([[1927, 586], [2786, 586], [2786, 659], [1927, 659]], 'ARTISTIC MILLINERS (PVT) LTD:', 0.6554757958545161), ([[3538, 578], [3856, 578], [3856, 650], [3538, 650]], '2645727-OA', 0.6866556761991387), ([[337, 646], [1511, 646], [1511, 724], [337, 724]], 'Plot No. 1/A Sector 20, Korangi Industrial Area,', 0.7408384940602638), ([[1927, 646], [3101, 646], [3101, 724], [1927, 724]], 'Plot No. I/A Sector 20, Korangi Industrial Area,', 0.5683741197709564), ([[3724, 669], [3958, 669], [3958, 731], [3724, 731]], 'GST NO.', 0.940978008574557), ([[368, 725], [628, 725], [628, 791], [368, 791]], 'KARACHI', 0.9811579114538505), ([[1958, 725], [2222, 725], [2222, 791], [1958, 791]], 'KARACHI', 0.8053183403474531), ([[3548, 755], [4031, 755], [4031, 817], [3548, 817]], '17-50-5205-002-82', 0.8066660607655057), ([[338, 802], [623, 802], [623, 864], [338, 864]], 'PAKISTAN', 0.8059223449338591), ([[1928, 802], [2157, 802], [2157, 868], [1928, 868]], 'Pakistan', 0.9999753861149948), ([[3660, 841], [4065, 841], [4065, 907], [3660, 907]], 'INVOICE DATE', 0.9944096425822814), ([[3578, 927], [3867, 927], [3867, 993], [3578, 993]], '05-APR-22', 0.9818108125663226), ([[3690, 1004], [4048, 1004], [4048, 1070], [3690, 1070]], 'INVOICE NO:', 0.981164106197087), ([[3496, 1095], [3696, 1095], [3696, 1160], [3496, 1160]], '577795', 0.999991969939624), ([[3449, 1180], [3734, 1180], [3734, 1246], [3449, 1246]], 'AACCOUNT', 0.8564915789270185), ([[3948, 1180], [4117, 1180], [4117, 1246], [3948, 1246]], 'PAGE', 0.9999569654464722), ([[3561, 1266], [3764, 1266], [3764, 1328], [3561, 1328]], '477034', 0.8438260472370438), ([[4017, 1267], [4111, 1267], [4111, 1323], [4017, 1323]], '415', 0.48438212275505066), ([[89, 1395], [933, 1395], [933, 1461], [89, 1461]], 'SOLD TO: LEVI STRAUSS & CO', 0.8695066141854718), ([[957, 1395], [1096, 1395], [1096, 1461], [957, 1461]], '2707', 0.4901506315523079), ([[59, 1567], [374, 1567], [374, 1633], [59, 1633]], 'ORDER NO_', 0.8944539750152717), ([[549, 1567], [903, 1567], [903, 1633], [549, 1633]], 'PO NUMBER', 0.9980373608103214), ([[1481, 1567], [1887, 1567], [1887, 1633], [1481, 1633]], 'TRACKING NO.', 0.992403614615304), ([[2534, 1567], [2780, 1567], [2780, 1633], [2534, 1633]], 'SHIP VIA', 0.7704563984472584), ([[3647, 1567], [4117, 1567], [4117, 1633], [3647, 1633]], 'FREIGHT TERMS', 0.5663295580998369), ([[158, 1653], [417, 1653], [417, 1715], [158, 1715]], '74740867', 0.9981362875426726), ([[549, 1653], [1079, 1653], [1079, 1719], [549, 1719]], 'EXPORT ACCOUNT', 0.9993732335743583), ([[1473, 1666], [1882, 1666], [1882, 1732] ...
# ===============Type===================== <class 'list'>
# ====================Length=============== 137
# Wall time: 1min 23s

# %%
type(text)
# Out:
# list

# %%
lst=[]
for i in range(length):
    #print(i," = ",output[i][1])
#     print(text[i][1])
    lst.append(text[i][1])
lst
# Out:
# ['Doc#t: FM-L3-SC-01',
#  'PAXAR',
#  'Issue#t: 02',
#  'SALES INVOICE',
#  'Issue Date: 25-10-2019',
#  'Paxar Pakistan (Pvt) Ltd_',
#  'SALES TAX REGISTRATION NO 17-50-5807-003-82',
#  'Plot # 26_',
#  'NATIONAL TAX NO 2695980-1',
#  'Sector 24',
#  'Korangi Industrial Area,',
#  'BILL TO',
#  'SHIP TO',
#  'NTN NO_',
#  'ARTISTIC MILLINERS (PVT) LTD:',
#  'ARTISTIC MILLINERS (PVT) LTD:',
#  '2645727-OA',
#  'Plot No. 1/A Sector 20, Korangi Industrial Area,',
#  'Plot No. I/A Sector 20, Korangi Industrial Area,',
#  'GST NO.',
#  'KARACHI',
#  'KARACHI',
#  '17-50-5205-002-82',
#  'PAKISTAN',
#  'Pakistan',
#  'INVOICE DATE',
#  '05-APR-22',
#  'INVOICE NO:',
#  '577795',
#  'AACCOUNT',
#  'PAGE',
#  '477034',
#  '415',
#  'SOLD TO: LEVI STRAUSS & CO',
#  '2707',
#  'ORDER NO_',
#  'PO NUMBER',
#  'TRACKING NO.',
#  'SHIP VIA',
#  'FREIGHT TERMS',
#  '74740867',
#  'EXPORT ACCOUNT',
#  'Kashif Rasheed',
#  'LOCAL',
#  'EXW EX WORKS',
#  'LINE',
#  'PART NUMBERIDESCRIPTION',
#  'QTY SHIPPED',
#  'UOM',
#  'UNIT PRICE',
#  'EXTENDED PRICETAX RATE',
#  'TAX AMOUNT',
#  'TOTAL AMOUNT',
#  '113',
#  'S112445',
#  'LEVI STRAUSS & CO.S112445.Monadnock',
#  '1,020.00  Each',
#  '3.64',
#  '3,712.801',
#  '17.00,',
#  '631.18',
#  '4,343.98',
#  'PC1OO',
#  'NF-6881140-6.',
#  'ORDER NO. 74740867 , Buyer PO#4515038022',
#  'Job#20070 PO#36421, DELIVERY INFO',
#  'AVY -',
#  '21721252/05-APR-22',
#  'HS Code: 4821.1040; Description: 48-a-Paper &',
#  'Paperboard, Rolls',
#  'Sheets',
#  '14',
#  'S112445',
#  'LEVI STRAUSS & CO.S112445.Monadnock',
#  '220.00  Each',
#  '3.64',
#  '800.80',
#  '17.00:',
#  '136.14',
#  '936.94',
#  'PC1OO',
#  'NF-6881140-6._',
#  'ORDER NO. 74740867 , Buyer PO#4515038176',
#  'Job#20070 PO#36421, DELIVERY INFO',
#  'AVY -',
#  '21721252/05-APR-22',
#  'HS Code: 4821.1040; Description: 48-a-Paper &',
#  'Paperboard, Rolls',
#  'Sheets',
#  '15',
#  'S112445',
#  'LEVI STRAUSS & CO.S112445.Monadnock',
#  '208.00  Each',
#  '3.64',
#  '757.12]',
#  '17.00;7',
#  '128.71',
#  '885.83',
#  'PC1OO',
#  'NF-6881140-6.',
#  'ORDER NO: 74740867 , Buyer PO#4530018916',
#  'Job#20070 PO#36421, DELIVERY INFO',
#  'AVY -',
#  '21721252/05-APR-22',
#  'HS Code: 4821.1040; Description: 48-a-Paper &',
#  'Paperboard, Rolls',
#  'Sheets',
#  '16',
#  'S112445',
#  'LEVI STRAUSS & CO.S112445.Monadnock',
#  '1,216.00 {Each',
#  '3.64',
#  '4,426.241',
#  '17.00;',
#  '752.46',
#  '5,178.70',
#  'PC1OO',
#  'NF-6881140-6.',
#  'ORDER NO. 74740867, Buyer POH4532015601',
#  'Job#20070 PO#36421 , DELIVERY INFO : AVY -',
#  '21721252/05-APR-22',
#  'HS Code: 4821.1040; Description: 48-a-Paper &',
#  'Paperboard, Rolls',
#  'Sheets',
#  'Immediately upon receipt of goods the Buyer is responsible for inspecting the contents of all shipments and deliveries to',
#  "assure that specifications have been met prior to incorporating the aforesaid products into Buyer's Products.",
#  'If the',
#  'lforesaid products fail to meet specifications, Buyer may return the non-conforming products for replacement or credit',
#  'within 5 days of receipt: In no event will Seller be responsible for damages or consequential damages other than credit',
#  'pr replacement: If there is any problem, please contact the Customer Service',
#  'This is also considered as Sales Tax invoice UIS 23 of Sales Tax Act; 1990',
#  'This is a system Generated Document and does not require any Signature/Approval',
#  'The above-mentioned products may be subject to U.S. law: Re-export or transfer to restricted countries or denied parties contrary to U.S. or local law is strictly prohibited without the prior',
#  'consent in writing of',
#  "Dennison's Law Department.",
#  'If the delivery date is stated the delivery date will be considered as date of the achievement_',
#  'Avery']

# %%
for i in range(length):
    print(i," = ",lst[i])
# Out:
# 0  =  Doc#t: FM-L3-SC-01
# 1  =  PAXAR
# 2  =  Issue#t: 02
# 3  =  SALES INVOICE
# 4  =  Issue Date: 25-10-2019
# 5  =  Paxar Pakistan (Pvt) Ltd_
# 6  =  SALES TAX REGISTRATION NO 17-50-5807-003-82
# 7  =  Plot # 26_
# 8  =  NATIONAL TAX NO 2695980-1
# 9  =  Sector 24
# 10  =  Korangi Industrial Area,
# 11  =  BILL TO
# 12  =  SHIP TO
# 13  =  NTN NO_
# 14  =  ARTISTIC MILLINERS (PVT) LTD:
# 15  =  ARTISTIC MILLINERS (PVT) LTD:
# 16  =  2645727-OA
# 17  =  Plot No. 1/A Sector 20, Korangi Industrial Area,
# 18  =  Plot No. I/A Sector 20, Korangi Industrial Area,
# 19  =  GST NO.
# 20  =  KARACHI
# 21  =  KARACHI
# 22  =  17-50-5205-002-82
# 23  =  PAKISTAN
# 24  =  Pakistan
# 25  =  INVOICE DATE
# 26  =  05-APR-22
# 27  =  INVOICE NO:
# 28  =  577795
# 29  =  AACCOUNT
# 30  =  PAGE
# 31  =  477034
# 32  =  415
# 33  =  SOLD TO: LEVI STRAUSS & CO
# 34  =  2707
# 35  =  ORDER NO_
# 36  =  PO NUMBER
# 37  =  TRACKING NO.
# 38  =  SHIP VIA
# 39  =  FREIGHT TERMS
# 40  =  74740867
# 41  =  EXPORT ACCOUNT
# 42  =  Kashif Rasheed
# 43  =  LOCAL
# 44  =  EXW EX WORKS
# 45  =  LINE
# 46  =  PART NUMBERIDESCRIPTION
# 47  =  QTY SHIPPED
# 48  =  UOM
# 49  =  UNIT PRICE
# 50  =  EXTENDED PRICETAX RATE
# 51  =  TAX AMOUNT
# 52  =  TOTAL AMOUNT
# 53  =  113
# 54  =  S112445
# 55  =  LEVI STRAUSS & CO.S112445.Monadnock
# 56  =  1,020.00  Each
# 57  =  3.64
# 58  =  3,712.801
# 59  =  17.00,
# 60  =  631.18
# 61  =  4,343.98
# 62  =  PC1OO
# 63  =  NF-6881140-6.
# 64  =  ORDER NO. 74740867 , Buyer PO#4515038022
# 65  =  Job#20070 PO#36421, DELIVERY INFO
# 66  =  AVY -
# 67  =  21721252/05-APR-22
# 68  =  HS Code: 4821.1040; Description: 48-a-Paper &
# 69  =  Paperboard, Rolls
# 70  =  Sheets
# 71  =  14
# 72  =  S112445
# 73  =  LEVI STRAUSS & CO.S112445.Monadnock
# 74  =  220.00  Each
# 75  =  3.64
# 76  =  800.80
# 77  =  17.00:
# 78  =  136.14
# 79  =  936.94
# 80  =  PC1OO
# 81  =  NF-6881140-6._
# 82  =  ORDER NO. 74740867 , Buyer PO#4515038176
# 83  =  Job#20070 PO#36421, DELIVERY INFO
# 84  =  AVY -
# 85  =  21721252/05-APR-22
# 86  =  HS Code: 4821.1040; Description: 48-a-Paper &
# 87  =  Paperboard, Rolls
# 88  =  Sheets
# 89  =  15
# 90  =  S112445
# 91  =  LEVI STRAUSS & CO.S112445.Monadnock
# 92  =  208.00  Each
# 93  =  3.64
# 94  =  757.12]
# 95  =  17.00;7
# 96  =  128.71
# 97  =  885.83
# 98  =  PC1OO
# 99  =  NF-6881140-6.
# 100  =  ORDER NO: 74740867 , Buyer PO#4530018916
# 101  =  Job#20070 PO#36421, DELIVERY INFO
# 102  =  AVY -
# 103  =  21721252/05-APR-22
# 104  =  HS Code: 4821.1040; Description: 48-a-Paper &
# 105  =  Paperboard, Rolls
# 106  =  Sheets
# 107  =  16
# 108  =  S112445
# 109  =  LEVI STRAUSS & CO.S112445.Monadnock
# 110  =  1,216.00 {Each
# 111  =  3.64
# 112  =  4,426.241
# 113  =  17.00;
# 114  =  752.46
# 115  =  5,178.70
# 116  =  PC1OO
# 117  =  NF-6881140-6.
# 118  =  ORDER NO. 74740867, Buyer POH4532015601
# 119  =  Job#20070 PO#36421 , DELIVERY INFO : AVY -
# 120  =  21721252/05-APR-22
# 121  =  HS Code: 4821.1040; Description: 48-a-Paper &
# 122  =  Paperboard, Rolls
# 123  =  Sheets
# 124  =  Immediately upon receipt of goods the Buyer is responsible for inspecting the contents of all shipments and deliveries to
# 125  =  assure that specifications have been met prior to incorporating the aforesaid products into Buyer's Products.
# 126  =  If the
# 127  =  lforesaid products fail to meet specifications, Buyer may return the non-conforming products for replacement or credit
# 128  =  within 5 days of receipt: In no event will Seller be responsible for damages or consequential damages other than credit
# 129  =  pr replacement: If there is any problem, please contact the Customer Service
# 130  =  This is also considered as Sales Tax invoice UIS 23 of Sales Tax Act; 1990
# 131  =  This is a system Generated Document and does not require any Signature/Approval
# 132  =  The above-mentioned products may be subject to U.S. law: Re-export or transfer to restricted countries or denied parties contrary to U.S. or local law is strictly prohibited without the prior
# 133  =  consent in writing of
# 134  =  Dennison's Law Department.
# 135  =  If the delivery date is stated the delivery date will be considered as date of the achievement_
# 136  =  Avery

# %%
import json

# %%
type(text[102][1])
po=text[102][1]
a=po.split(" ")
a
# Out:
# ['AVY', '-']

# %%
data_set = {#"Party_PO": [output[36][1]],
            "National_Tax_No.": [text[16][1]],
            'Invoice No':[text[28][1]],
            'Ordered No':[text[82][1]],
            'Sold to':[text[33][1]],
            'Page No':[text[33][1]],
            "PO# ":text[119][1]
           }
    

#json_dump = json.dumps(data_set)


print(data_set)
# Out:
# {'National_Tax_No.': ['2645727-OA'], 'Invoice No': ['577795'], 'Ordered No': ['ORDER NO. 74740867 , Buyer PO#4515038176'], 'Sold to': ['SOLD TO: LEVI STRAUSS & CO'], 'Page No': ['SOLD TO: LEVI STRAUSS & CO'], 'PO# ': 'Job#20070 PO#36421 , DELIVERY INFO : AVY -'}

# %%
json_object = json.loads(json_dump)


print(json_object)

# %%
out_file = open("invoice.json", "w") 
    
json.dump(data_set, out_file, indent = 6) 
    
out_file.close()
