# %%
import matplotlib.pyplot as plt
import cv2
import os
import sys
import pytesseract
from pytesseract import Output
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract'

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import easyocr
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# %%time
from PIL import Image
import pytesseract
import sys
from pdf2image import convert_from_path
import os
  
# Path of the pdf
PDF_file = "C:\\Users\\Naeem\\OCR\\chem\\chem.pdf"
  
'''
Part #1 : Converting PDF to images
'''
  
# Store all the pages of the PDF in a variable
pages = convert_from_path(PDF_file, 500)
  
# Counter to store images of each page of PDF to image
image_counter = 1
  
# Iterate through all the pages stored above
for page in pages:
  
    # Declaring filename for each page of PDF as JPG
    # For each page, filename will be:
    # PDF page 1 -> page_1.jpg
    # PDF page 2 -> page_2.jpg
    # PDF page 3 -> page_3.jpg
    # ....
    # PDF page n -> page_n.jpg
    filename = "page_"+str(image_counter)+".jpg"
      
    # Save the image of the page in system
    page.save(filename, 'JPEG')
  
    # Increment the counter to update filename
    image_counter = image_counter + 1

'''
Part #2 - Recognizing text from the images using OCR
'''
    
# Variable to get count of total number of pages
filelimit = image_counter-1
  
# Creating a text file to write the output
outfile = "out_text.txt"
  
# Open the file in append mode so that 
# All contents of all images are added to the same file
f = open(outfile, "a")
  
# Iterate from 1 to total number of pages
for i in range(1, filelimit + 1):
  
    # Set filename to recognize text from
    # Again, these files will be:
    # page_1.jpg
    # page_2.jpg
    # ....
    # page_n.jpg
    filename = "page_"+str(i)+".jpg"
          
    # Recognize the text as string in image using pytesserct
    #text = str(((pytesseract.image_to_string(Image.open(filename)))))
    text = reader.readtext(filename)
    
    
    
    
    print(text)
    print("===============Type=====================",type(text))
    length=len(text)
    print("====================Length===============",length)
    
    # The recognized text is stored in variable text
    # Any string processing may be applied on text
    # Here, basic formatting has been done:
    # In many PDFs, at line ending, if a word can't
    # be written fully, a 'hyphen' is added.
    # The rest of the word is written in the next line
    # Eg: This is a sample text this word here GeeksF-
    # orGeeks is half on first line, remaining on next.
    # To remove this, we replace every '-\n' to ''.
    #text = text.replace('-\n', '')    
    texts=str(text)
    # Finally, write the processed text to the file.
    f.write(texts)
  
# Close the file after writing all the text.
f.close()
# Out:
# [([[237, 173], [523, 173], [523, 298], [237, 298]], '{CCL', 0.5672629475593567), ([[2800, 111], [3769, 111], [3769, 282], [2800, 282]], 'SALES TAX', 0.9132765208142165), ([[187, 389], [623, 389], [623, 454], [187, 454]], 'Excelent Through', 0.999507664952028), ([[2887, 300], [3682, 300], [3682, 473], [2887, 473]], 'INVOICE', 0.9998584280589169), ([[158, 439], [336, 439], [336, 505], [158, 505]], 'Quality', 0.9962564379303356), ([[401, 439], [637, 439], [637, 506], [401, 506]], 'Quality Is', 0.9988934569222425), ([[239, 500], [545, 500], [545, 549], [239, 549]], 'Our Success', 0.7629037740665788), ([[170, 565], [1608, 565], [1608, 663], [170, 663]], 'CHEM COLOR INTERNATIONAL', 0.7835051457841131), ([[168, 672], [1422, 672], [1422, 744], [168, 744]], 'C-I-43 SECTOR L-1, SURJANI TOWN KARACHI', 0.5186305810813059), ([[173, 779], [656, 779], [656, 844], [173, 844]], 'National Tax No', 0.7388641528279288), ([[742, 783], [1041, 783], [1041, 844], [742, 844]], '1437878-7', 0.5052241289337278
# ===============Type===================== <class 'list'>
# ====================Length=============== 104
# Wall time: 1min 17s

# %%
type(text)
# Out:
# list

# %%
lst=[]
for i in range(length):
    #print(i," = ",output[i][1])
#     print(text[i][1])
    lst.append(text[i][1])
lst
# Out:
# ['{CCL',
#  'SALES TAX',
#  'Excelent Through',
#  'INVOICE',
#  'Quality',
#  'Quality Is',
#  'Our Success',
#  'CHEM COLOR INTERNATIONAL',
#  'C-I-43 SECTOR L-1, SURJANI TOWN KARACHI',
#  'National Tax No',
#  '1437878-7',
#  'Invoice Date',
#  '17-Aug-2019',
#  'Sales Tax No',
#  '11-02-9999-741-82',
#  'Invoice No',
#  'SI-CCI-01503',
#  'Phone',
#  '92-36910085-6-7',
#  'Payment Mode',
#  '90 DAYS',
#  'Fax',
#  'Payment Due Date',
#  '15-Nov-2019',
#  '~Email',
#  'accounts@chemcolorintl.com',
#  'Currency',
#  'PAK RUPEES',
#  'Web',
#  'wwW.chemcolorintl.com',
#  'Exrate',
#  '1.00',
#  'S.0 #',
#  'LSO-CCI-01901',
#  'BUYER',
#  'Party P.o # :',
#  '76457,',
#  'M/S :',
#  'ARTISTIC MILLINERS (PVT) LTD # 4',
#  'Department',
#  'Address',
#  '37-F B, BLOCK 6, PE.C.H.S, SHARA E',
#  'FAISAL, KARACHI',
#  'Phone',
#  'DC No.',
#  '20050,20051,',
#  'National Tax No',
#  '2645727-0',
#  'Sales Tax No',
#  '17-50-5205-002-82',
#  'EXCLUDING',
#  'GST',
#  'INCLUDING',
#  'S.No:',
#  'ITEM',
#  'WEIGHT',
#  'RATE',
#  'GST AMT .',
#  'CARTAGE',
#  'DISCOUNT',
#  'VALUE',
#  '%o',
#  'VALUE',
#  'UREA',
#  '1,500.00',
#  '40.00',
#  '60,000.00',
#  '17.00',
#  '10,200.00',
#  '0.00',
#  '0.00',
#  '70,200',
#  'Total',
#  '1,500.00',
#  '60,000.001',
#  '10,200.00',
#  '0.00',
#  '0.00',
#  '70,200',
#  'AMOUNT IN WORDS',
#  'Seventy Thousand_Two Hundred',
#  'Onlx',
#  'GS+',
#  'Reu i Se',
#  "'Kvev",
#  '2 %',
#  '6',
#  'ITEM DESCRIPTION',
#  '29-a-Organic Chemicals,',
#  'MXhi ',
#  'OTHER COMMENTS',
#  'Ox dw',
#  'Av',
#  'Qwcb-k',
#  'Please include the Bill no on your cheque:',
#  'MMx , Anec (',
#  'V',
#  'Receiver Name',
#  'Received By',
#  'AUTHORIZED BY',
#  'Thank You For Your Business',
#  'ISSUED BY',
#  'Naeled',
#  'Z410410335']

# %%
for i in range(length):
    print(i," = ",lst[i])
# Out:
# 0  =  {CCL
# 1  =  SALES TAX
# 2  =  Excelent Through
# 3  =  INVOICE
# 4  =  Quality
# 5  =  Quality Is
# 6  =  Our Success
# 7  =  CHEM COLOR INTERNATIONAL
# 8  =  C-I-43 SECTOR L-1, SURJANI TOWN KARACHI
# 9  =  National Tax No
# 10  =  1437878-7
# 11  =  Invoice Date
# 12  =  17-Aug-2019
# 13  =  Sales Tax No
# 14  =  11-02-9999-741-82
# 15  =  Invoice No
# 16  =  SI-CCI-01503
# 17  =  Phone
# 18  =  92-36910085-6-7
# 19  =  Payment Mode
# 20  =  90 DAYS
# 21  =  Fax
# 22  =  Payment Due Date
# 23  =  15-Nov-2019
# 24  =  ~Email
# 25  =  accounts@chemcolorintl.com
# 26  =  Currency
# 27  =  PAK RUPEES
# 28  =  Web
# 29  =  wwW.chemcolorintl.com
# 30  =  Exrate
# 31  =  1.00
# 32  =  S.0 #
# 33  =  LSO-CCI-01901
# 34  =  BUYER
# 35  =  Party P.o # :
# 36  =  76457,
# 37  =  M/S :
# 38  =  ARTISTIC MILLINERS (PVT) LTD # 4
# 39  =  Department
# 40  =  Address
# 41  =  37-F B, BLOCK 6, PE.C.H.S, SHARA E
# 42  =  FAISAL, KARACHI
# 43  =  Phone
# 44  =  DC No.
# 45  =  20050,20051,
# 46  =  National Tax No
# 47  =  2645727-0
# 48  =  Sales Tax No
# 49  =  17-50-5205-002-82
# 50  =  EXCLUDING
# 51  =  GST
# 52  =  INCLUDING
# 53  =  S.No:
# 54  =  ITEM
# 55  =  WEIGHT
# 56  =  RATE
# 57  =  GST AMT .
# 58  =  CARTAGE
# 59  =  DISCOUNT
# 60  =  VALUE
# 61  =  %o
# 62  =  VALUE
# 63  =  UREA
# 64  =  1,500.00
# 65  =  40.00
# 66  =  60,000.00
# 67  =  17.00
# 68  =  10,200.00
# 69  =  0.00
# 70  =  0.00
# 71  =  70,200
# 72  =  Total
# 73  =  1,500.00
# 74  =  60,000.001
# 75  =  10,200.00
# 76  =  0.00
# 77  =  0.00
# 78  =  70,200
# 79  =  AMOUNT IN WORDS
# 80  =  Seventy Thousand_Two Hundred
# 81  =  Onlx
# 82  =  GS+
# 83  =  Reu i Se
# 84  =  'Kvev
# 85  =  2 %
# 86  =  6
# 87  =  ITEM DESCRIPTION
# 88  =  29-a-Organic Chemicals,
# 89  =  MXhi
# 90  =  OTHER COMMENTS
# 91  =  Ox dw
# 92  =  Av
# 93  =  Qwcb-k
# 94  =  Please include the Bill no on your cheque:
# 95  =  MMx , Anec (
# 96  =  V
# 97  =  Receiver Name
# 98  =  Received By
# 99  =  AUTHORIZED BY
# 100  =  Thank You For Your Business
# 101  =  ISSUED BY
# 102  =  Naeled
# 103  =  Z410410335

# %%
listy=[]
a=0
while lst[63+a]!="Total":
    listy.append(lst[63+a:72+a])
    a=a+9
    
print(listy)
# Out:
# [['UREA', '1,500.00', '40.00', '60,000.00', '17.00', '10,200.00', '0.00', '0.00', '70,200']]

# %%
import json

data_set = {"Party_PO": [text[36][1]],
            "National_Tax_No.": [text[10][1]],
            "Data_Item":listy
           }
    

json_dump = json.dumps(data_set)


print(json_dump)
# Out:
# {"Party_PO": ["76457,"], "National_Tax_No.": ["1437878-7"], "Data_Item": [["UREA", "1,500.00", "40.00", "60,000.00", "17.00", "10,200.00", "0.00", "0.00", "70,200"]]}
